# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %%
#Create lists and counters
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Build a parameter and url in order to request results in Farhenheit
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

params = {
    'appid':weather_api_key,
    'units':units
}

# %%
print("Beginning Data Retrieval ")
print("-------------------------")

#Loop through the cities
for index, city in enumerate(cities, start = 1):
    try:
        params['q'] = city
        response = requests.get(url=base_url, params=params)
        request_url = response.url
        data = response.json()
        city_name_list.append(data["name"])
        cloudiness_list.append(data["clouds"]["all"])
        country_list.append(data["sys"]["country"])
        date_list.append(data["dt"])
        humidity_list.append(data["main"]["humidity"])
        lat_list.append(data["coord"]["lat"])
        lng_list.append(data["coord"]["lon"])
        max_temp_list.append(data['main']['temp_max'])
        wind_speed_list.append(data["wind"]["speed"])
        
        if counter > 49:
            counter = 0
            set_counter = set_counter + 1
    
        else:
            counter = counter + 1
            
        print(f"Processing Record {counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 : dikson
# Processing Record 2 of Set 1 : hobart
# Processing Record 3 of Set 1 : punta arenas
# City not found. Skipping...
# Processing Record 4 of Set 1 : nemuro
# Processing Record 5 of Set 1 : ust-ilimsk
# Processing Record 6 of Set 1 : norman wells
# Processing Record 7 of Set 1 : kodinsk
# Processing Record 8 of Set 1 : atuona
# Processing Record 9 of Set 1 : idenao
# Processing Record 10 of Set 1 : igrim
# Processing Record 11 of Set 1 : puerto ayora
# Processing Record 12 of Set 1 : klaksvik
# Processing Record 13 of Set 1 : kahului
# Processing Record 14 of Set 1 : barrow
# Processing Record 15 of Set 1 : codrington
# Processing Record 16 of Set 1 : vardo
# Processing Record 17 of Set 1 : thaba nchu
# Processing Record 18 of Set 1 : marquette
# Processing Record 19 of Set 1 : hamilton
# Processing Record 20 of Set 1 : parana
# Processing Record 21 of Set 1 : yellowknife
# City not found. Skipping...
# Processing Record 22 of Set 1 : saint-philippe
# Processing Record 23 of Set 1 : east london
# Processing Record 24 of Set 1 : san patricio
# Processing Record 25 of Set 1 : hasaki
# Processing Record 26 of Set 1 : mar del plata
# Processing Record 27 of Set 1 : mattru
# Processing Record 28 of Set 1 : bredasdorp
# Processing Record 29 of Set 1 : rikitea
# Processing Record 30 of Set 1 : broome
# City not found. Skipping...
# Processing Record 31 of Set 1 : crotone
# Processing Record 32 of Set 1 : nabire
# City not found. Skipping...
# Processing Record 33 of Set 1 : tiksi
# Processing Record 34 of Set 1 : ushuaia
# Processing Record 35 of Set 1 : manavalakurichi
# Processing Record 36 of Set 1 : dali
# Processing Record 37 of Set 1 : sidi ali
# Processing Record 38 of Set 1 : ulaangom
# Processing Record 39 of Set 1 : hilo
# Processing Record 40 of Set 1 : port augusta
# Processing Record 41 of Set 1 : namatanai
# Processing Record 42 of Set 1 : jamestown
# Processing Record 43 of Set 1 : bluff
# Processing Record 44 of Set 1 : sept-iles
# Processing Record 45 of Set 1 : busselton
# Processing Record 46 of Set 1 : srednekolymsk
# Processing Record 47 of Set 1 : mahebourg
# Processing Record 48 of Set 1 : nikolskoye
# Processing Record 49 of Set 1 : longyearbyen
# Processing Record 50 of Set 1 : katobu
# Processing Record 0 of Set 2 : new norfolk
# Processing Record 1 of Set 2 : beisfjord
# Processing Record 2 of Set 2 : balabac
# Processing Record 3 of Set 2 : qaanaaq
# Processing Record 4 of Set 2 : akdepe
# Processing Record 5 of Set 2 : vaini
# Processing Record 6 of Set 2 : esperance
# Processing Record 7 of Set 2 : victoria
# Processing Record 8 of Set 2 : mataura
# Processing Record 9 of Set 2 : caravelas
# City not found. Skipping...
# Processing Record 10 of Set 2 : castro
# Processing Record 11 of Set 2 : gongzhuling
# Processing Record 12 of Set 2 : arraial do cabo
# Processing Record 13 of Set 2 : butaritari
# Processing Record 14 of Set 2 : petropavlovsk-kamchatskiy
# Processing Record 15 of Set 2 : lompoc
# Processing Record 16 of Set 2 : litovko
# Processing Record 17 of Set 2 : kapaa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 2 : morant bay
# Processing Record 19 of Set 2 : worcester
# Processing Record 20 of Set 2 : bassano
# Processing Record 21 of Set 2 : alofi
# Processing Record 22 of Set 2 : ranong
# Processing Record 23 of Set 2 : albany
# Processing Record 24 of Set 2 : kodiak
# Processing Record 25 of Set 2 : hami
# Processing Record 26 of Set 2 : wenling
# Processing Record 27 of Set 2 : east longmeadow
# Processing Record 28 of Set 2 : provideniya
# Processing Record 29 of Set 2 : kimbe
# Processing Record 30 of Set 2 : davila
# Processing Record 31 of Set 2 : katsuura
# Processing Record 32 of Set 2 : marawi
# Processing Record 33 of Set 2 : pisco
# Processing Record 34 of Set 2 : walvis bay
# Processing Record 35 of Set 2 : leningradskiy
# Processing Record 36 of Set 2 : gunjur
# Processing Record 37 of Set 2 : shubarkuduk
# Processing Record 38 of Set 2 : inta
# Processing Record 39 of Set 2 : rio grande
# Processing Record 40 of Set 2 : gizo
# City not found. Skipping...
# Processing Record 41 of Set 2 : dekar
# Processing Record 42 of Set 2 : port lincoln
# Processing Record 43 of Set 2 : padang
# Processing Record 44 of Set 2 : qurayyat
# Processing Record 45 of Set 2 : sao miguel do araguaia
# Processing Record 46 of Set 2 : mainit
# Processing Record 47 of Set 2 : eydhafushi
# Processing Record 48 of Set 2 : oparino
# Processing Record 49 of Set 2 : prescott
# Processing Record 50 of Set 2 : staryy nadym
# Processing Record 0 of Set 3 : sigli
# Processing Record 1 of Set 3 : waingapu
# City not found. Skipping...
# Processing Record 2 of Set 3 : vrangel
# City not found. Skipping...
# Processing Record 3 of Set 3 : chapleau
# Processing Record 4 of Set 3 : mbini
# Processing Record 5 of Set 3 : bonavista
# Processing Record 6 of Set 3 : geraldton
# Processing Record 7 of Set 3 : hermanus
# Processing Record 8 of Set 3 : shimizu
# Processing Record 9 of Set 3 : bethel
# Processing Record 10 of Set 3 : ahipara
# Processing Record 11 of Set 3 : kyshtovka
# Processing Record 12 of Set 3 : syke
# Processing Record 13 of Set 3 : san quintin
# Processing Record 14 of Set 3 : saint george
# Processing Record 15 of Set 3 : tuatapere
# Processing Record 16 of Set 3 : atbasar
# Processing Record 17 of Set 3 : pevek
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set
# Processing Record 31 of Set 4 : aksu
# Processing Record 32 of Set 4 : telemaco borba
# Processing Record 33 of Set 4 : gazimurskiy zavod
# Processing Record 34 of Set 4 : ostrovnoy
# Processing Record 35 of Set 4 : kutahya
# City not found. Skipping...
# Processing Record 36 of Set 4 : flic en flac
# Processing Record 37 of Set 4 : marystown
# Processing Record 38 of Set 4 : acajutla
# Processing Record 39 of Set 4 : sinaloa
# Processing Record 40 of Set 4 : roald
# Processing Record 41 of Set 4 : firovo
# Processing Record 42 of Set 4 : phan thiet
# Processing Record 43 of Set 4 : labuhan
# Processing Record 44 of Set 4 : korla
# Processing Record 45 of Set 4 : odessa
# Processing Record 46 of Set 4 : chingirlau
# Processing Record 47 of Set 4 : carnarvon
# Processing Record 48 of Set 4 : pithora
# City not found. Skipping...
# Processing Record 49 of Set 4 : airai
# Processing Record 50 of Set 4 : goderich
# Processing Record 0 of Set 5 : ponta delgada
# Processing Record 1 of Set 5 : san cristobal
# Processing Record 2 of Set 5 : lvov
# Processing Record 3 of Set 5 : pangnirtung
# Processing Record 4 of Set 5 : camacha
# Processing Record 5 of Set 5 : havre-saint-pierre
# Processing Record 6 of Set 5 : coihaique
# Processing Record 7 of Set 5 : kemin
# Processing Record 8 of Set 5 : mae hong son
# Processing Record 9 of Set 5 : tocopilla
# Processing Record 10 of Set 5 : dingle
# Processing Record 11 of Set 5 : codajas
# Processing Record 12 of Set 5 : sorland
# City not found. Skipping...
# Processing Record 13 of Set 5 : ribeira grande
# City not found. Skipping...
# Processing Record 14 of Set 5 : nanortalik
# Processing Record 15 of Set 5 : nanakuli
# Processing Record 16 of Set 5 : sao filipe
# Processing Record 17 of Set 5 : linxia
# Processing Record 18 of Set 5 : igarka
# Processing Record 19 of Set 5 : saint-pierre
# Processing Record 20 of Set 5 : coquimbo
# Processing Record 21 of Set 5 : cabo san lucas
# Processing Record 22 of Set 5 : pangody
# Processing Record 23 of Set 5 : haines junction
# Processing Record 24 of Set 5 : vao
# Processing Record 25 of Set 5 : pochutla
# City not found. Skipping...
# Processing Record 26 of Set 5 : russell
# Processing Record 27 of Set 5 : bayanday
# Processing Record 28 of Set 5 : upernavik
# Processing Record 29 of Set 5 : chokurdakh
# Processing Record 30 of Set 5 : goundam
# Processing Record 31 of Set 5 : tual
# Processing Record 32 of Set 5 : angoche
# Processing Record 33 of Set 5 : alpena
# Processing Record 34 of Set 5 : los llanos de aridane
# Processing Record 35 of Set 5 : port blair
# Processing Record 36 of Set 5 : changtu
# Processing Record 37 of Set 5 : ust-barguzin
# Processing Record 38 of Set 5 : bambous virieux
# Processing Record 39 of Set 5 : beira
# Processing Record 40 of Set 5 : petauke
# Processing Record 41 of Set 5 : clyde river
# Processing Record 42 of Set 5 : ust-omchug
# Processing Record 43 of Set 5 : sao joao da barra
# Processing Record 44 of Set 5 : souillac
# Processing Record 45 of Set 5 : aktau
# Processing Record 46 of Set 5 : yar-sale
# Processing Record 47 of Set 5 : contamana
# Processing Record 48 of Set 5 : palmer
# Processing Record 49 of Set 5 : mantua
# Processing Record 50 of Set 5 : lebu
# Processing Record 0 of Set 6 : waslala
# Processing Record 1 of Set 6 : imeni poliny osipenko
# Processing Record 2 of Set 6 : piacabucu
# Processing Record 3 of Set 6 : georgetown
# City not found. Skipping...
# Processing Record 4 of Set 6 : kavieng
# Processing Record 5 of Set 6 : barraute
# Processing Record 6 of Set 6 : hovd
# Processing Record 7 of Set 6 : komsomolskiy
# Processing Record 8 of Set 6 : buala
# Processing Record 9 of Set 6 : riyadh
# Processing Record 10 of Set 6 : shipitsyno
# Processing Record 11 of Set 6 : cheremukhovo
# Processing Record 12 of Set 6 : mana
# Processing Record 13 of Set 6 : corinto
# City not found. Skipping...
# Processing Record 14 of Set 6 : baoding
# Processing Record 15 of Set 6 : bar harbor
# Processing Record 16 of Set 6 : juneau
# Processing Record 17 of Set 6 : avarua
# Processing Record 18 of Set 6 : sawtell
# Processing Record 19 of Set 6 : batagay-alyta
# Processing Record 20 of Set 6 : faanui
# Processing Record 21 of Set 6 : ilulissat
# Processing Record 22 of Set 6 : tura
# Processing Record 23 of Set 6 : dezful
# Processing Record 24 of Set 6 : jaciara
# Processing Record 25 of Set 6 : kralendijk
# Processing Record 26 of Set 6 : springbok
# Processing Record 27 of Set 6 : beloha
# City not found. Skipping...
# Processing Record 28 of Set 6 : ancud
# Processing Record 29 of Set 6 : chapais
# Processing Record 30 of Set 6 : grindavik
# Processing Record 31 of Set 6 : muros
# Processing Record 32 of Set 6 : lorengau
# Processing Record 33 of Set 6 : luanda
# City not found. Skipping...
# Processing Record 34 of Set 6 : vostok
# Processing Record 35 of Set 6 : vertou
# Processing Record 36 of Set 6 : pedro ii
# Processing Record 37 of Set 6 : dwarka
# Processing Record 38 of Set 6 : ballina
# Processing Record 39 of Set 6 : marmashen
# Processing Record 40 of Set 6 : qiryat gat
# City not found. Skipping...
# Processing Record 41 of Set 6 : sao felix do xingu
# Processing Record 42 of Set 6 : luderitz
# Processing Record 43 of Set 6 : verkhnevilyuysk
# Processing Record 44 of Set 6 : itoman
# Processing Record 45 of Set 6 : puerto baquerizo moreno
# Processing Record 46 of Set 6 : karratha
# Processing Record 47 of Set 6 : khani
# Processing Record 48 of Set 6 : birao
# Processing Record 49 of Set 6 : ingham
# Processing Record 50 of Set 6 : harper
# Processing Record 0 of Set 7 : lagoa
# Processing Record 1 of Set 7 : birobidzhan
# Processing Record 2 of Set 7 : shankargarh
# Processing Record 3 of Set 7 : kattivakkam
# Processing Record 4 of Set 7 : wagar
# Processing Record 5 of Set 7 : vallenar
# Processing Record 6 of Set 7 : manadhoo
# Processing Record 7 of Set 7 : saint anthony
# Processing Record 8 of Set 7 : grandola
# Processing Record 9 of Set 7 : mazagao
# Processing Record 10 of Set 7 : mimongo
# Processing Record 11 of Set 7 : smithers
# Processing Record 12 of Set 7 : stonehaven
# Processing Record 13 of Set 7 : inuvik
# Processing Record 14 of Set 7 : kununurra
# Processing Record 15 of Set 7 : hingoli
# City not found. Skipping...
# Processing Record 16 of Set 7 : akranes
# Processing Record 17 of Set 7 : nelson bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 7 : qingquan
# Processing Record 19 of Set 7 : jinchang
# City not found. Skipping...
# Processing Record 20 of Set 7 : pangkalanbuun
# City not found. Skipping...
# Processing Record 21 of Set 7 : hobyo
# Processing Record 22 of Set 7 : sicuani
# Processing Record 23 of Set 7 : omsk
# Processing Record 24 of Set 7 : suileng
# Processing Record 25 of Set 7 : filadelfia
# Processing Record 26 of Set 7 : taguatinga
# Processing Record 27 of Set 7 : kyren
# Processing Record 28 of Set 7 : itum-kale
# Processing Record 29 of Set 7 : hasanabad
# City not found. Skipping...
# Processing Record 30 of Set 7 : fairbanks
# Processing Record 31 of Set 7 : brokopondo
# Processing Record 32 of Set 7 : college
# Processing Record 33 of Set 7 : jumla
# Processing Record 34 of Set 7 : mount gambier
# Processing Record 35 of Set 7 : harstad
# Processing Record 36 of Set 7 : mogadishu
# Processing Record 37 of Set 7 : the valley
# Processing Record 38 of Set 7 : ginda
# Processing Record 39 of Set 7 : atambua
# Processing Record 40 of Set 7 : vila velha
# Processing Record 41 of Set 7 : kaiwaka
# Processing Record 42 of Set 7 : taltal
# Processing Record 43 of Set 7 : guerrero negro
# Processing Record 44 of Set 7 : mildura
# Processing Record 45 of Set 7 : daurala
# Processing Record 46 of Set 7 : sola
# Processing Record 47 of Set 7 : brae
# Processing Record 48 of Set 7 : cockburn town
# Processing Record 49 of Set 7 : serro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 7 : santa flavia
# Processing Record 0 of Set 8 : kavaratti
# Processing Record 1 of Set 8 : muroto
# Processing Record 2 of Set 8 : avera
# Processing Record 3 of Set 8 : hualmay
# Processing Record 4 of Set 8 : springfield
# Processing Record 5 of Set 8 : teguise
# Processing Record 6 of Set 8 : pegnitz
# Processing Record 7 of Set 8 : vanderhoof
# Processing Record 8 of Set 8 : simao
# Processing Record 9 of Set 8 : kaoma
# Processing Record 10 of Set 8 : umm lajj
# Processing Record 11 of Set 8 : dicabisagan
# Processing Record 12 of Set 8 : tomatlan
# Processing Record 13 of Set 8 : nizwa
# Processing Record 14 of Set 8 : sitka
# Processing Record 15 of Set 8 : asau
# Processing Record 16 of Set 8 : oktyabrskoye
# Processing Record 17 of Set 8 : port macquarie
# Processing Record 18 of Set 8 : lasa
# Processing Record 19 of Set 8 : lobito
# Processing Record 20 of Set 8 : esmeraldas
# Processing Record 21 of Set 8 : miles city
# Processing Record 22 of Set 8 : fortuna
# Processing Record 23 of Set 8 : tabas
# Processing Record 24 of Set 8 : touba
# Processing Record 25 of Set 8 : uthal
# Processing Record 26 of Set 8 : xifeng
# Processing Record 27 of Set 8 : esso
# Processing Record 28 of Set 8 : evensk
# Processing Record 29 of Set 8 : bagotville
# Processing Record 30 of Set 8 : meulaboh
# Processing Record 15 of Set 11 : viransehir
# Processing Record 16 of Set 11 : aginskoye
# Processing Record 17 of Set 11 : corrente
# Processing Record 18 of Set 11 : uyuni
# City not found. Skipping...
# Processing Record 19 of Set 11 : sibu
# Processing Record 20 of Set 11 : kitoy
# Processing Record 21 of Set 11 : hazaribag
# Processing Record 22 of Set 11 : yarada
# Processing Record 23 of Set 11 : beringovskiy
# Processing Record 24 of Set 11 : ishimbay
# Processing Record 25 of Set 11 : yamada
# City not found. Skipping...
# Processing Record 26 of Set 11 : tabou
# Processing Record 27 of Set 11 : izhma
# Processing Record 28 of Set 11 : okmulgee
# Processing Record 29 of Set 11 : mercedes
# Processing Record 30 of Set 11 : gorontalo
# Processing Record 31 of Set 11 : melilla
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
cities_weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp (F)" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
cities_weather_dict.count()
# Out:
# City            541
# Cloudiness      541
# Country         541
# Date            541
# Humidity        541
# Lat             541
# Lng             541
# Max Temp (F)    541
# Wind Speed      541
# dtype: int64

# %%
cities_weather_dict
# Out:
#              City  Cloudiness Country        Date  Humidity      Lat  \
# 0          Dikson         100      RU  1632532411        87  73.5069
# 1          Hobart          40      AU  1632532411        61 -42.8794
# 2    Punta Arenas          90      CL  1632532170        75 -53.1500
# 3          Nemuro           0      JP  1632532412        68  43.3236
# 4     Ust'-Ilimsk          24      RU  1632532412        74  58.0006
# ..            ...         ...     ...         ...       ...      ...
# 536         Izhma          11      RU  1632532593        87  65.0083
# 537      Okmulgee           1      US  1632532593        46  35.6234
# 538      Mercedes           0      AR  1632532594        88 -34.6515
# 539     Gorontalo          40      ID  1632532594        69   0.5412
# 540       Melilla          75      ES  1632532594        94  35.2937
#
#           Lng  Max Temp (F)  Wind Speed
# 0     80.5464         35.92       15.57
# 1    147.3294         50.05        1.99
# 2    -70.9167         41.11        6.91
# 3    145.5750         57.88       14.88
# 4    102.6619         36.18        1.63
# ..        ...           ...         ...
# 536   53.9113         40.21        8.14
# 537  -95.9605         79.52        3.44
# 538  -59.4307         57.85        8.23
# 539  123.0595         84.81        3.00
# 540   -2.9383         71.80        5.75
#
# [541 rows x 9 columns]

# %%
#Save this dataframe data into a csv file
cities_weather_dict.to_csv('../output_data/cities.csv', index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_weather_dict.loc[cities_weather_dict['Humidity'] >= 100]
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 181  Prince Rupert          90      CA  1632532386       100  54.3161
# 189      Marystown           4      CA  1632532474       100  47.1666
# 372  Oktyabr'skoye         100      RU  1632532537       100  43.0645
# 399          Mahon          90      ES  1632532546       100  39.8885
# 410           Aras           0      ES  1632532549       100  42.5617
# 457   Örnsköldsvik          90      SE  1632532566       100  63.2909
# 531         Yārāda          75      IN  1632532591       100  17.6500
#
#           Lng  Max Temp (F)  Wind Speed
# 181 -130.3201         53.69        8.05
# 189  -55.1483         53.85        5.99
# 372   44.7417         48.34        6.71
# 399    4.2658         73.96        5.75
# 410   -2.3560         63.05        2.30
# 457   18.7153         41.95        2.30
# 531   83.2667         80.92        2.30

# %%
#All cities either have a humidity <= 100%, nothing higher.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Generate a scatter plot
plt.scatter(cities_weather_dict['Lat'], cities_weather_dict['Max Temp (F)'], marker='o', facecolor='steelblue', edgecolor='black')

#Add required labels
plt.title(f'City Latitude vs Max Temperature (09/23/21)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

#Set grid lines
plt.grid(linestyle='-', linewidth=1, alpha=0.5)

#Save plot as an image
plt.savefig("../Images/Latitude vs Max Temperature.png")

# %% [markdown]
# This plot is looking at the relationship between latitude and temperature. As the latitude approaches 0 (the equator), the higher the temperature becomes. As The latitude fluctuates below or above 0, the temperature drops.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Generate a scatter plot
plt.scatter(cities_weather_dict['Lat'], cities_weather_dict['Humidity'], marker='o', facecolor='steelblue', edgecolor='black')

#Add required labels
plt.title(f'City Latitiude vs Humidity (09/23/21)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

#Set grid lines
plt.grid(linestyle='-', linewidth=1, alpha=0.5)

#Save plot as an image
plt.savefig("../Images/Latitude vs Humidity.png")

# %% [markdown]
# This plot is looking at the relationship between latitude and humidity percentage. It emphasizes that humidity is not necessarily defined by the latitude of a region.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Generate a scatter plot
plt.scatter(cities_weather_dict['Lat'], cities_weather_dict['Cloudiness'], marker='o', facecolor='steelblue', edgecolor='black')

#Add required labels
plt.title(f'City Latitiude vs Cloudiness (09/23/21)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

#Set grid lines
plt.grid(linestyle='-', linewidth=1, alpha=0.5)

#Save plot as an image
plt.savefig("../Images/Latitude vs Cloudiness.png")

# %% [markdown]
# This plot is looking at the relationship between latitude and cloudiness percentage. It is demonstrating that cloudiness data is widely spread across the latitude, similarly to humidity.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Generate a scatter plot
plt.scatter(cities_weather_dict['Lat'], cities_weather_dict['Wind Speed'], marker='o', facecolor='steelblue', edgecolor='black')

#Add required labels
plt.title(f'City Latitiude vs Wind Speed (mph) (09/23/21)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

#Set grid lines
plt.grid(linestyle='-', linewidth=1, alpha=0.5)

#Save plot as an image
plt.savefig("../Images/Latitude vs Wind Speed.png")

# %% [markdown]
# This plot is looking at the relationship between latitude and wind speed in mph. Due to the way the data is spread, it slightly shows that the further away from the equator, generally the wind speed is higher.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = cities_weather_dict.loc[cities_weather_dict["Lat"] >= 0]
southern_hemisphere = cities_weather_dict.loc[cities_weather_dict["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp (F)"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Max Temperature (F) in the Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

#Set limits
plt.ylim(0, 105)
plt.xlim(0, 80)

#Save plot as an image
plt.savefig("../Images/N_H Latitude vs Max Temperature.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:-0.86

# %% [markdown]
# The relationship between latitude and max temperature for northern hemisphere cities is strongly negative, given that it's r-squared value is very close to -1. The closer the city to the equator (at 0) the higher the max temperature, which further supports the fundamental ask of how the weather is in cities near the equator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp (F)"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Max Temperature (F) in the Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

#Set limits
plt.ylim(40, 100)
plt.xlim(-65,10)

#Save plot as an image
plt.savefig("../Images/S_H Latitude vs Max Temperature.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:0.74

# %% [markdown]
# The relationship between latitude and max temperature for southern hemisphere cities is relatively strong, given that it's r-squared value is above 0.7. The closer the city to the equator (at 0) the higher the max temperature, which further supports the fundamental ask of how the weather is in cities near the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Humidity (%) in the Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

#Set limits
plt.ylim(0, 105)
plt.xlim(0, 80)

#Save plot as an image
plt.savefig("../Images/N_H Latitude vs Humidity.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:0.02

# %% [markdown]
# The relationship between latitude and the humidity percentage for northern hemisphere cities is very weakly positive, given that it's r-squared value is very close to 0. There seems to be no concrete relationship in regards to humidity levels amongst the cities and their location.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Humidity (%) in the Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

#Set limits
plt.ylim(0, 105)
plt.xlim(-60,10)

#Save plot as an image
plt.savefig("../Images/S_H Latitude vs Humidity.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:0.09

# %% [markdown]
# The relationship between latitude and the humidity percentage for southern hemisphere cities is very weak as well, given that it's r-squared value is very close to 0. There seems to be no concrete relationship in regards to humidity levels amongst the cities and their location.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Cloudiness (%) in the Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

#Set limits
plt.ylim(-5, 105)
plt.xlim(0, 80)

#Save plot as an image
plt.savefig("../Images/N_H Latitude vs Cloudiness.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:0.04

# %% [markdown]
# The relationship between latitude and the cloudiness percentage for northern hemisphere cities is very weakly positive, given that it's r-squared value is very close to 0. There seems to be no concrete relationship in regards to cloudiness amongst the cities and their location.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Cloudiness (%) in the Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

#Set limits
plt.ylim(-5, 105)
plt.xlim(0, -60)

#Save plot as an image
plt.savefig("../Images/S_H Latitude vs Cloudiness.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:0.06

# %% [markdown]
# The relationship between latitude and the cloudiness percentage for southern hemisphere cities is very weak as well, given that it's r-squared value is very close to 0. There seems to be no concrete relationship in regards to cloudiness amongst the cities and their location.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Wind Speed (mph) in the Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

#Set limits
plt.ylim(0,40)
plt.xlim(0, 80)

#Save plot as an image
plt.savefig("../Images/N_H Latitude vs Wind Speed.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:0.16

# %% [markdown]
# The relationship between latitude and the wind speed in mph for northern hemisphere cities is very weakly positive, given that it's r-squared value is very close to 0. There seems to be no concrete relationship in regards to wind speed amongst the cities and their location given how scattered the data seems. There is a very minimal increase in wind speed when the city is further away from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Define x and y values
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

#Create the line regression, line equation and r value
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'The r-squared value is:{round(st.pearsonr(x_values,y_values)[0],2)}')

#Create the scatter plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=12,color="red")

#Add required labels
plt.title('Latitude vs Wind Speed (mph) in the Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

#Set limits
plt.ylim(0,35)
plt.xlim(-60,5)

#Save plot as an image
plt.savefig("../Images/S_H Latitude vs Wind Speed.png")

#Print plot
plt.tight_layout()
plt.show()
# Out:
# The r-squared value is:-0.15

# %% [markdown]
# The relationship between latitude and the wind speed in mph for southern hemisphere cities is very weakly negative, given that it's r-squared value is very close to 0. There seems to be no concrete relationship in regards to wind speed amongst the cities and their location due to how scattered the data is.
